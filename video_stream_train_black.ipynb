# %% [markdown]
# # Video stream train

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import cv2
import random
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from pathlib import Path

from keras.layers.core import Dense,Flatten
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam

# %%
if tf.test.gpu_device_name(): 
    print('Default GPU Device:{}'.format(tf.test.gpu_device_name()))
else:
    print("Please install GPU version of TF")
# Out:
# Default GPU Device:/device:GPU:0

# %% [markdown]
# ## Dataset creation

# %% [markdown]
# Nico
# 0: angry
# 1: calm
# 2: disgust
# 3: fear
# 4: happy
# 5: sad
# 6: surprise

# %%
emotions = {0:'neutral', 1:'calm', 2:'happy', 3:'sad', 4:'angry', 5:'fear', 6:'disgust', 7:'surprise'}
emotional_intensity = {1:'normal', 2:'strong'}

dataset_path = "Datasets/RAVDESS_frames_black/"

height_targ = 224
width_targ = 224
height_orig = height_targ
width_orig = width_targ

batch_size = 64
num_classes = len(emotions)

val_actors = ['21', '22']
test_actors = ['23', '24']

# %%
filenames_train = [] # train
filenames_val = [] # validation

for (dirpath, dirnames, fn) in os.walk(dataset_path):
    if fn != []:
        if any(act in dirpath for act in (test_actors+val_actors))==False:  # select only train actors
            path = [os.path.join(dirpath, elem) for elem in fn]
            label = [int(fn[0].split('-')[2]) - 1] * len(fn)
            filenames_train.append(list(zip(path, label)))
        if any(act in dirpath for act in val_actors):                       # select only validation actors
            path = [os.path.join(dirpath, elem) for elem in fn]
            label = [int(fn[0].split('-')[2]) - 1] * len(fn)
            filenames_val.append(list(zip(path, label)))

# %%
# image = tf.io.read_file(filenames_train[0][0][0])
# image = tf.image.decode_jpeg(image, channels=3)
# image = tf.image.convert_image_dtype(image, dtype=tf.float16)
# image = tf.image.resize(image, [height_orig, width_orig])

# image = image.numpy()
# for i, elem in enumerate(image):
#     for j, val in enumerate(elem):
#         if np.sum(val) > 2.7:
#             image[i][j] = np.array([0, 0, 0])
# image = tf.convert_to_tensor(image)

# plt.imshow(image)

# %%
def sampling(list, num_frames_desired):
    tot = []
    for elem in list:
        sampled_list = random.sample(elem, num_frames_desired)
        tot += sampled_list
    return(tot)

def parse_image(filename):
    image = tf.io.read_file(filename)
    image = tf.image.decode_jpeg(image, channels=3)
    image = tf.image.convert_image_dtype(image, dtype=tf.float16)
    image = tf.image.resize(image, [height_orig, width_orig])
    print('shape frames:', image.shape)
    return image

def configure_for_performance(ds):
    ds = ds.shuffle(buffer_size=1000) # serve?
    ds = ds.batch(batch_size)
    ds = ds.repeat()
    ds = ds.prefetch(buffer_size=tf.data.experimental.AUTOTUNE)
    return ds

def load_dataset(filenames, batch_size):
    frames_per_vid = min([len(elem) for elem in filenames])     # number of frames per clip in order to have balanced classes
    print("frames per video:", frames_per_vid) 

    filenames_sampled = sampling(filenames, frames_per_vid)
    random.shuffle(filenames_sampled)

    zipped = [list(t) for t in zip(*filenames_sampled)]

    names = zipped[0]
    labels = zipped[1]

    names = tf.data.Dataset.from_tensor_slices(names)
    images = names.map(parse_image, num_parallel_calls=tf.data.experimental.AUTOTUNE)

    labels = [elem for elem in labels]
    labels = tf.data.Dataset.from_tensor_slices(labels)

    ds = tf.data.Dataset.zip((images, labels))
    ds = configure_for_performance(ds)

    frame_number = len(filenames_sampled)
    step_per_epoch = frame_number // batch_size
    print('frames number:', frame_number, '\nbatch size:', batch_size, '\nbatch number:', step_per_epoch)
    return ds, step_per_epoch

# %%
train_ds, step_per_epoch_train = load_dataset(filenames_train, batch_size)
# Out:
# frames per video: 23
# shape frames: (224, 224, 3)
# frames number: 27600
# batch size: 64
# batch number: 431

# %%
val_ds, step_per_epoch_val = load_dataset(filenames_val, batch_size)
# Out:
# frames per video: 28
# shape frames: (224, 224, 3)
# frames number: 3360
# batch size: 64
# batch number: 52

# %%
a = train_ds.unbatch().take(1)

for elem in a:
    o = tf.image.resize_with_crop_or_pad(elem[0], height_targ, width_targ)
    
    print(elem[0].shape)
    print(emotions[int(elem[1])])
plt.imshow(o)
# Out:
# (224, 224, 3)
# calm

# %%
data_augmentation = tf.keras.Sequential([
    layers.RandomFlip("horizontal"),
    # layers.CenterCrop(height_targ, width_targ),
    # layers.RandomBrightness(0.5), # da verificare
    # layers.RandomContrast(0.5) # da verificare
    # layers.RandomRotation(0.2),
    layers.RandomZoom(height_factor=(-0.1, 0.1))
])

# %%
for images, labels in train_ds.take(1):
    plt.figure(figsize=(10, 10))
    # print(labels)
    first_image = images[0]
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        augmented_image = data_augmentation(
            tf.expand_dims(first_image, 0), training=True
        )
        plt.imshow(augmented_image[0])
        plt.title(emotions[int(labels[0])])
        plt.axis("off")

# %% [markdown]
# ## Transfer Learning ResNet50

# %%
checkpoint_filepath = './Models/Video_stream/video_model{epoch:02d}-{val_loss:.2f}.hdf5'

reduce_lr = keras.callbacks.ReduceLROnPlateau(monitor="val_sparse_categorical_accuracy", factor=0.5, patience=2, verbose=1)
early_stop = keras.callbacks.EarlyStopping( monitor="val_sparse_categorical_accuracy", patience=4, verbose=1, restore_best_weights=True)
save_best = keras.callbacks.ModelCheckpoint(filepath=checkpoint_filepath,
                                            monitor='val_sparse_categorical_accuracy',
                                            mode='max',
                                            save_best_only=True)

# %%
version = 3
arc = 'resnet'
epochs_train = 50
epochs_tune = 10
lr_train = 0.001
lr_tune = 0.00001
momentum = 0.5

# %%
pretrained_model = keras.applications.ResNet50(include_top=False,
                                                input_shape=(height_targ, width_targ, 3),
                                                weights='imagenet',
                                                pooling='avg')
pretrained_model.trainable = False


inputs = keras.layers.Input(shape=(height_orig, width_orig, 3))

x = data_augmentation(inputs)

x = pretrained_model(x, training=False) # `training=False` important for fine-tuning
# x = keras.layers.GlobalAveragePooling2D()(x)
# x = keras.layers.Dropout(0.2)(x) 
x = keras.layers.Dense(512, activation='relu')(x)
outputs = keras.layers.Dense(num_classes, activation='softmax')(x)
model = keras.Model(inputs, outputs)

model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  sequential (Sequential)     (None, 224, 224, 3)       0
#
#  resnet50 (Functional)       (None, 2048)              23587712
#
#  dense (Dense)               (None, 512)               1049088
#
#  dense_1 (Dense)             (None, 8)                 4104
#
# =================================================================
# Total params: 24,640,904
# Trainable params: 1,053,192
# Non-trainable params: 23,587,712
# _________________________________________________________________

# %% [markdown]
# ### Train top layer

# %%
model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=lr_train),
    # optimizer=keras.optimizers.SGD(learning_rate=learningrate, momentum=momentum)
    loss=keras.losses.sparse_categorical_crossentropy,
    metrics=[keras.metrics.sparse_categorical_accuracy, keras.metrics.sparse_top_k_categorical_accuracy],
)


history = model.fit(train_ds,
                    epochs=epochs_train,
                    validation_data=val_ds,
                    batch_size=batch_size,
                    steps_per_epoch=step_per_epoch_train,
                    validation_steps=step_per_epoch_val,
                    # callbacks=[reduce_lr, early_stop, save_best],
                    # callbacks=[reduce_lr, save_best],
                    verbose=1)
# Out:
# Epoch 1/50
# 431/431 [==============================] - 203s 455ms/step - loss: 2.0926 - sparse_categorical_accuracy: 0.1432 - sparse_top_k_categorical_accuracy: 0.6781 - val_loss: 2.0597 - val_sparse_categorical_accuracy: 0.1328 - val_sparse_top_k_categorical_accuracy: 0.6644
# Epoch 2/50
# 431/431 [==============================] - 183s 423ms/step - loss: 2.0581 - sparse_categorical_accuracy: 0.1558 - sparse_top_k_categorical_accuracy: 0.6948 - val_loss: 2.0591 - val_sparse_categorical_accuracy: 0.1340 - val_sparse_top_k_categorical_accuracy: 0.6671
# Epoch 3/50
# 431/431 [==============================] - 184s 426ms/step - loss: 2.0523 - sparse_categorical_accuracy: 0.1542 - sparse_top_k_categorical_accuracy: 0.6982 - val_loss: 2.0509 - val_sparse_categorical_accuracy: 0.1349 - val_sparse_top_k_categorical_accuracy: 0.6857
# Epoch 4/50
# 431/431 [==============================] - 181s 420ms/step - loss: 2.0423 - sparse_categorical_accuracy: 0.1701 - sparse_top_k_categorical_accuracy: 0.7180 - val_loss: 2.0522 - val_sparse_categorical_accuracy: 0.1710 - val_sparse_top_k_categorical_accuracy: 0.7251
# Epoch 5/50
# 431/431 [==============================] - 179s 416ms/step - loss: 2.0276 - sparse_categorical_accuracy: 0.1859 - sparse_top_k_categorical_accuracy: 0.7396 - val_loss: 2.0467 - val_sparse_categorical_accuracy: 0.1361 - val_sparse_top_k_categorical_accuracy: 0.7091
# Epoch 6/50
# 431/431 [==============================] - 180s 419ms/step - loss: 2.0135 - sparse_categorical_accuracy: 0.1960 - sparse_top_k_categorical_accuracy: 0.7561 - val_loss: 2.0265 - val_sparse_categorical_accuracy: 0.1938 - val_sparse_top_k_categorical_accuracy: 0.7136
# Epoch 7/50
# 431/431 [==============================] - 179s 415ms/step - loss: 1.9901 - sparse_categorical_accuracy: 0.2072 - sparse_top_k_categorical_accuracy: 0.7781 - val_loss: 2.0380 - val_sparse_categorical_accuracy: 0.1710 - val_sparse_top_k_categorical_accuracy: 0.7458
# Epoch 8/50
# 431/431 [==============================] - 179s 416ms/step - loss: 1.9657 - sparse_categorical_accuracy: 0.2291 - sparse_top_k_categorical_accuracy: 0.7943 - val_loss: 1.9980 - val_sparse_categorical_accuracy: 0.1755 - val_sparse_top_k_categorical_accuracy: 0.8026
# Epoch 9/50
# 431/431 [==============================] - 179s 416ms/step - loss: 1.9451 - sparse_categorical_accuracy: 0.2371 - sparse_top_k_categorical_accuracy: 0.8073 - val_loss: 1.9885 - val_sparse_categorical_accuracy: 0.2353 - val_sparse_top_k_categorical_accuracy: 0.7834
# Epoch 10/50
# 431/431 [==============================] - 179s 415ms/step - loss: 1.9258 - sparse_categorical_accuracy: 0.2428 - sparse_top_k_categorical_accuracy: 0.8188 - val_loss: 1.9889 - val_sparse_categorical_accuracy: 0.1773 - val_sparse_top_k_categorical_accuracy: 0.7569
# Epoch 11/50
# 431/431 [==============================] - 180s 417ms/step - loss: 1.9039 - sparse_categorical_accuracy: 0.2554 - sparse_top_k_categorical_accuracy: 0.8256 - val_loss: 1.9744 - val_sparse_categorical_accuracy: 0.2181 - val_sparse_top_k_categorical_accuracy: 0.7764
# Epoch 12/50
# 431/431 [==============================] - 179s 416ms/step - loss: 1.8888 - sparse_categorical_accuracy: 0.2625 - sparse_top_k_categorical_accuracy: 0.8304 - val_loss: 1.9605 - val_sparse_categorical_accuracy: 0.1992 - val_sparse_top_k_categorical_accuracy: 0.8080
# Epoch 13/50
# 431/431 [==============================] - 179s 415ms/step - loss: 1.8777 - sparse_categorical_accuracy: 0.2674 - sparse_top_k_categorical_accuracy: 0.8321 - val_loss: 1.9894 - val_sparse_categorical_accuracy: 0.2037 - val_sparse_top_k_categorical_accuracy: 0.7978
# Epoch 14/50
# 431/431 [==============================] - 179s 415ms/step - loss: 1.8663 - sparse_categorical_accuracy: 0.2702 - sparse_top_k_categorical_accuracy: 0.8353 - val_loss: 1.9708 - val_sparse_categorical_accuracy: 0.2073 - val_sparse_top_k_categorical_accuracy: 0.7665
# Epoch 15/50
# 431/431 [==============================] - 179s 416ms/step - loss: 1.8459 - sparse_categorical_accuracy: 0.2792 - sparse_top_k_categorical_accuracy: 0.8490 - val_loss: 2.0037 - val_sparse_categorical_accuracy: 0.1836 - val_sparse_top_k_categorical_accuracy: 0.7308
# Epoch 16/50
# 431/431 [==============================] - 179s 417ms/step - loss: 1.8316 - sparse_categorical_accuracy: 0.2818 - sparse_top_k_categorical_accuracy: 0.8540 - val_loss: 1.9754 - val_sparse_categorical_accuracy: 0.1905 - val_sparse_top_k_categorical_accuracy: 0.7707
# Epoch 17/50
# 431/431 [==============================] - 179s 416ms/step - loss: 1.8149 - sparse_categorical_accuracy: 0.2947 - sparse_top_k_categorical_accuracy: 0.8585 - val_loss: 1.9552 - val_sparse_categorical_accuracy: 0.2004 - val_sparse_top_k_categorical_accuracy: 0.8179
# Epoch 18/50
# 431/431 [==============================] - 179s 416ms/step - loss: 1.8039 - sparse_categorical_accuracy: 0.2971 - sparse_top_k_categorical_accuracy: 0.8644 - val_loss: 1.9782 - val_sparse_categorical_accuracy: 0.1965 - val_sparse_top_k_categorical_accuracy: 0.7614
# Epoch 19/50
# 431/431 [==============================] - 180s 417ms/step - loss: 1.7847 - sparse_categorical_accuracy: 0.3087 - sparse_top_k_categorical_accuracy: 0.8704 - val_loss: 1.9611 - val_sparse_categorical_accuracy: 0.1923 - val_sparse_top_k_categorical_accuracy: 0.7710
# Epoch 20/50
# 431/431 [==============================] - 179s 414ms/step - loss: 1.7810 - sparse_categorical_accuracy: 0.3086 - sparse_top_k_categorical_accuracy: 0.8714 - val_loss: 2.0679 - val_sparse_categorical_accuracy: 0.2031 - val_sparse_top_k_categorical_accuracy: 0.7145
# Epoch 21/50
# 431/431 [==============================] - 180s 419ms/step - loss: 1.7744 - sparse_categorical_accuracy: 0.3145 - sparse_top_k_categorical_accuracy: 0.8700 - val_loss: 1.9485 - val_sparse_categorical_accuracy: 0.2191 - val_sparse_top_k_categorical_accuracy: 0.8122
# Epoch 22/50
# 431/431 [==============================] - 179s 416ms/step - loss: 1.7631 - sparse_categorical_accuracy: 0.3169 - sparse_top_k_categorical_accuracy: 0.8739 - val_loss: 2.0272 - val_sparse_categorical_accuracy: 0.1824 - val_sparse_top_k_categorical_accuracy: 0.8224
# Epoch 23/50
# 431/431 [==============================] - 180s 417ms/step - loss: 1.7458 - sparse_categorical_accuracy: 0.3236 - sparse_top_k_categorical_accuracy: 0.8802 - val_loss: 2.0112 - val_sparse_categorical_accuracy: 0.1983 - val_sparse_top_k_categorical_accuracy: 0.7776
# Epoch 24/50
# 431/431 [==============================] - 179s 415ms/step - loss: 1.7301 - sparse_categorical_accuracy: 0.3338 - sparse_top_k_categorical_accuracy: 0.8839 - val_loss: 2.2173 - val_sparse_categorical_accuracy: 0.1854 - val_sparse_top_k_categorical_accuracy: 0.7767
# Epoch 25/50
# 431/431 [==============================] - 180s 417ms/step - loss: 1.7242 - sparse_categorical_accuracy: 0.3373 - sparse_top_k_categorical_accuracy: 0.8871 - val_loss: 2.1659 - val_sparse_categorical_accuracy: 0.1911 - val_sparse_top_k_categorical_accuracy: 0.7260
# Epoch 26/50
# 431/431 [==============================] - 182s 424ms/step - loss: 1.7125 - sparse_categorical_accuracy: 0.3442 - sparse_top_k_categorical_accuracy: 0.8893 - val_loss: 2.0945 - val_sparse_categorical_accuracy: 0.1986 - val_sparse_top_k_categorical_accuracy: 0.7975
# Epoch 27/50
# 431/431 [==============================] - 182s 422ms/step - loss: 1.7036 - sparse_categorical_accuracy: 0.3480 - sparse_top_k_categorical_accuracy: 0.8883 - val_loss: 2.0417 - val_sparse_categorical_accuracy: 0.2028 - val_sparse_top_k_categorical_accuracy: 0.7686
# Epoch 28/50
# 431/431 [==============================] - 182s 422ms/step - loss: 1.6980 - sparse_categorical_accuracy: 0.3476 - sparse_top_k_categorical_accuracy: 0.8937 - val_loss: 2.0667 - val_sparse_categorical_accuracy: 0.2007 - val_sparse_top_k_categorical_accuracy: 0.7816
# Epoch 29/50
# 431/431 [==============================] - 181s 420ms/step - loss: 1.6948 - sparse_categorical_accuracy: 0.3496 - sparse_top_k_categorical_accuracy: 0.8927 - val_loss: 2.1030 - val_sparse_categorical_accuracy: 0.1995 - val_sparse_top_k_categorical_accuracy: 0.7858
# Epoch 30/50
# 431/431 [==============================] - 179s 416ms/step - loss: 1.6900 - sparse_categorical_accuracy: 0.3484 - sparse_top_k_categorical_accuracy: 0.8938 - val_loss: 2.3075 - val_sparse_categorical_accuracy: 0.1812 - val_sparse_top_k_categorical_accuracy: 0.7061
# Epoch 31/50
# 431/431 [==============================] - 185s 428ms/step - loss: 1.6770 - sparse_categorical_accuracy: 0.3588 - sparse_top_k_categorical_accuracy: 0.8965 - val_loss: 2.1750 - val_sparse_categorical_accuracy: 0.2251 - val_sparse_top_k_categorical_accuracy: 0.7383
# Epoch 32/50
# 431/431 [==============================] - 186s 432ms/step - loss: 1.6693 - sparse_categorical_accuracy: 0.3616 - sparse_top_k_categorical_accuracy: 0.8982 - val_loss: 2.1828 - val_sparse_categorical_accuracy: 0.1968 - val_sparse_top_k_categorical_accuracy: 0.7539
# Epoch 33/50
# 431/431 [==============================] - 186s 433ms/step - loss: 1.6592 - sparse_categorical_accuracy: 0.3659 - sparse_top_k_categorical_accuracy: 0.8997 - val_loss: 2.3057 - val_sparse_categorical_accuracy: 0.1902 - val_sparse_top_k_categorical_accuracy: 0.7828
# Epoch 34/50
# 431/431 [==============================] - 186s 432ms/step - loss: 1.6478 - sparse_categorical_accuracy: 0.3722 - sparse_top_k_categorical_accuracy: 0.9030 - val_loss: 2.2209 - val_sparse_categorical_accuracy: 0.1965 - val_sparse_top_k_categorical_accuracy: 0.7752
# Epoch 35/50
# 354/431 [=======================>......] - ETA: 30s - loss: 1.6613 - sparse_categorical_accuracy: 0.3623 - sparse_top_k_categorical_accuracy: 0.9012
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_20724/3568505175.py in <module>
#       7
#       8
# ----> 9 history = model.fit(train_ds,
#      10                     epochs=epochs_train,
#      11                     validation_data=val_ds,
#
# c:\ProgramData\Anaconda3\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# c:\ProgramData\Anaconda3\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1407                 _r=1):
#    1408               callbacks.on_train_batch_begin(step)
# -> 1409               tmp_logs = self.train_function(iterator)
#    1410               if data_handler.should_sync:
#    1411                 context.async_wait()
#
# c:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\util\traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# c:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py in __call__(self, *args, **kwds)
#     913
#     914       with OptionalXlaContext(self._jit_compile):
# --> 915         result = self._call(*args, **kwds)
#     916
#     917       new_tracing_count = self.experimental_get_tracing_count()
#
# c:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py in _call(self, *args, **kwds)
#     945       # In this case we have created variables on the first call, so we run the
#     946       # defunned version which is guaranteed to never create variables.
# --> 947       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     948     elif self._stateful_fn is not None:
#     949       # Release the lock early so that multiple threads can perform the call
#
# c:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\eager\function.py in __call__(self, *args, **kwargs)
#    2451       (graph_function,
#    2452        filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 2453     return graph_function._call_flat(
#    2454         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    2455
#
# c:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\eager\function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1858         and executing_eagerly):
#    1859       # No tape is watching; skip to running the function.
# -> 1860       return self._build_call_outputs(self._inference_function.call(
#    1861           ctx, args, cancellation_manager=cancellation_manager))
#    1862     forward_backward = self._select_forward_and_backward_functions(
#
# c:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\eager\function.py in call(self, ctx, args, cancellation_manager)
#     495       with _InterpolateFunctionError(self):
#     496         if cancellation_manager is None:
# --> 497           outputs = execute.execute(
#     498               str(self.signature.name),
#     499               num_outputs=self._num_outputs,
#
# c:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52   try:
#      53     ctx.ensure_initialized()
# ---> 54     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                         inputs, attrs, num_outputs)
#      56   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
fig1 = plt.gcf()
plt.plot(history.history['sparse_categorical_accuracy'])
plt.plot(history.history['val_sparse_categorical_accuracy'])
plt.axis(ymin=0, ymax=1)
plt.grid()
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['train', 'validation'])
# plt.savefig('./Report/Plots/resnet1_2.png')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_20724/2142618905.py in <module>
#       1 fig1 = plt.gcf()
# ----> 2 plt.plot(history.history['sparse_categorical_accuracy'])
#       3 plt.plot(history.history['val_sparse_categorical_accuracy'])
#       4 plt.axis(ymin=0, ymax=1)
#       5 plt.grid()
#
# NameError: name 'history' is not defined

# %% [markdown]
# ### Fine tuning

# %%
pretrained_model.trainable = True
model.summary()

# %%
model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=lr_tune),
    # optimizer=keras.optimizers.SGD(learning_rate=learningrate, momentum=momentum)
    loss=keras.losses.sparse_categorical_crossentropy,
    metrics=[keras.metrics.sparse_categorical_accuracy, keras.metrics.sparse_top_k_categorical_accuracy],
)

history_fine = model.fit(train_ds,
                    epochs=epochs_tune,
                    validation_data=val_ds,
                    batch_size=batch_size,
                    steps_per_epoch=step_per_epoch_train,
                    validation_steps=step_per_epoch_val,
                    callbacks=[reduce_lr, save_best],
                    # callbacks=[reduce_lr, early_stop, save_best],
                    verbose=1)

# %%
fig1 = plt.gcf()
plt.plot(history_fine.history['sparse_categorical_accuracy'])
plt.plot(history_fine.history['val_sparse_categorical_accuracy'])
plt.axis(ymin=0,ymax=1)
plt.grid()
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['train', 'validation'])
# plt.savefig('./Report/Plots/resnet1_2.png')
plt.show()

# %% [markdown]
# ## Prove

# %%
# image = tf.io.read_file(filenames_train[0][0][0])
# image = cv2.imread(filenames_train[0][0][0], cv2.IMREAD_COLOR)
# image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
# image = image.astype(float) / 255

# height, width, _ = image.shape

# for i in range(height):
#     for j in range(width):
#         if image[i, j].sum() > 2.8:
#             image[i, j] = [0, 0, 0]

# # image = tf.image.convert_image_dtype(image, dtype=tf.float16)
# image = tf.image.resize(image, [height_orig, width_orig])
# plt.imshow(image)
# # image

# tf.data.Dataset.from_tensor_slices(filenames_train)
